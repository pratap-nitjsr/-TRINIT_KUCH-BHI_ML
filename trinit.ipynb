# %%
# !pip install gdown
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.1/720.1 kB 25.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# %%
# !gdown --id 1Qsu5KZgvOGmD3v1D1JDSpWJAqfTPyJPI
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Qsu5KZgvOGmD3v1D1JDSpWJAqfTPyJPI
# From (redirected): https://drive.usercontent.google.com/download?id=1Qsu5KZgvOGmD3v1D1JDSpWJAqfTPyJPI&confirm=t&uuid=4567c983-4bc0-4a75-ad2d-fadc2233e321
# To: /kaggle/working/TriNIT.zip
# 100%|████████████████████████████████████████| 957M/957M [00:11<00:00, 86.1MB/s]

# %%
# !unzip /kaggle/working/TriNIT.zip
# Out:
# Archive:  /kaggle/working/TriNIT.zip
#    creating: TriNIT/.idea/
#  extracting: TriNIT/.idea/.gitignore
#    creating: TriNIT/.idea/inspectionProfiles/
#   inflating: TriNIT/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: TriNIT/.idea/misc.xml
#   inflating: TriNIT/.idea/modules.xml
#   inflating: TriNIT/.idea/TriNIT.iml
#   inflating: TriNIT/.idea/workspace.xml
#   inflating: TriNIT/convert.py
#   inflating: TriNIT/data_clean.py
#   inflating: TriNIT/data_split.py
#   inflating: TriNIT/main.py
#   inflating: TriNIT/test.py
#    creating: TriNIT/test/
#    creating: TriNIT/test/images/
#   inflating: TriNIT/test/images/Czech_000010.jpg
#   inflating: TriNIT/test/images/Czech_000062.jpg
#   inflating: TriNIT/test/images/Czech_000064.jpg
#   inflating: TriNIT/test/images/Czech_000083.jpg
#   inflating: TriNIT/test/images/Czech_000108.jpg
#   inflating: TriNIT/test/images/Czech_000325.jpg
#   inflating: TriNIT/test/images/Czech_000343.jpg
# ...

# %%
# !gdown --id 1HqMxvZYPxVEOaOQ-QH0rJ0y4WuMrE8FV
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1HqMxvZYPxVEOaOQ-QH0rJ0y4WuMrE8FV
# To: /kaggle/working/data.yaml
# 100%|██████████████████████████████████████████| 202/202 [00:00<00:00, 1.12MB/s]

# %%
os.environ["WANDB_DISABLED"]='true'

# %%
base_model = YOLO('/kaggle/input/m1/other/v76/1/best (3).pt')
base_model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 274MB/s]

# %%
my_model = base_model.train(data = '/kaggle/working/data.yaml', epochs = 50, max_det=10, batch=-1 )
# Out:
# Ultralytics YOLOv8.1.25 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...
